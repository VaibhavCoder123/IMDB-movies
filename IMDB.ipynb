# %% [markdown]
# # Importing important libraries

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # Adding our dataset

# %%
dataframe = pd.read_csv('imbd.csv')

# %% [markdown]
# # List of our dataset

# %%
dataframe
# Out:
#      No_of_movies                                               Name  Year  \
# 0               1                                                      NaN
# 1               2                    #Gadhvi (He thought he was G...  2019
# 2               3                                        #Homecoming  2021
# 3               4                                            #Yaaram  2019
# 4               5                                  ...And Once Again  2010
# ..            ...                                                ...   ...
# 715           716                                             Agyaat  2009
# 716           717                                              Ahaan  2019
# 717           718                                     Aham Brahmasmi  2021
# 718           719                                           Ahankaar  1995
# 719           720                                            Ahankar  1999
#
#      Duration                   Genre  Rating  Votes  \
# 0         NaN                   Drama     NaN      2
# 1       109.0                   Drama     NaN      7
# 2        90.0          Drama, Musical     7.0      8
# 3       110.0         Comedy, Romance     NaN     50
# 4       105.0                   Drama     4.4     35
# ..        ...                     ...     ...    ...
# 715     130.0  Drama, Horror, Mystery     6.2      0
# 716      81.0           Comedy, Drama     2.9    620
# 717     106.0                  Action     7.2    213
# 718     145.0                   Drama     NaN      0
# 719      75.0                 -------     5.9     53
#
#                       Director              Actor 1             Actor 2  \
# 0                J.S. Randhawa             Manmauji              Birbal
# 1                Gaurav Bakshi         Rasika Dugal      Vivek Ghamande
# 2           Soumyajit Majumdar         Sayani Gupta   Plabita Borthakur
# 3                   Ovais Khan              Prateik          Ishita Raj
# 4                 Amol Palekar         Rajat Kapoor  Rituparna Sengupta
# ..                         ...                  ...                 ...
# 715            Ram Gopal Varma              Nithiin    Priyanka Kothari
# 716            Nikhil Pherwani         Arif Zakaria      Niharika Singh
# 717  Megastar Maharishi Aazaad              -------             -------
# 718           Ashim S. Samanta   Mithun Chakraborty      Mamta Kulkarni
# 719                 Raja Mitra  Soumitra Chatterjee      Indrani Haldar
#
#              Actor 3
# 0    Rajendra Bhatia
# 1      Arvind Jangid
# 2         Roy Angana
# 3    Siddhant Kapoor
# 4        Antara Mali
# ..               ...
# 715     Rasika Dugal
# 716     Abuli Mamaji
# 717          -------
# 718      Prem Chopra
# 719    Rajesh Sharma
#
# [720 rows x 11 columns]

# %% [markdown]
# # There are so many NaN items(not a number)

# %%
sns.heatmap(dataframe.isnull())
# Out:
# <Axes: >

# %%
dataframe.isnull().sum()
# Out:
# No_of_movies      0
#        Name       0
# Year             23
# Duration        348
# Genre             0
# Rating          298
# Votes             0
# Director          0
# Actor 1           0
# Actor 2           0
# Actor 3           0
# dtype: int64

# %%
dataframe.shape
# Out:
# (720, 11)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_movies  720 non-null    int64
#  1          Name   720 non-null    object
#  2   Year          697 non-null    object
#  3   Duration      372 non-null    float64
#  4   Genre         720 non-null    object
#  5   Rating        422 non-null    float64
#  6   Votes         720 non-null    int64
#  7   Director      720 non-null    object
#  8   Actor 1       720 non-null    object
#  9   Actor 2       720 non-null    object
#  10  Actor 3       720 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 62.0+ KB

# %% [markdown]
#  # So Many errors

# %% [markdown]
# # Lets try to remove errors(NaN values)

# %% [markdown]
# I have made 'Year' column clear here

# %%
dataframe['Year'] = pd.to_numeric(dataframe['Year'], errors='coerce')

# %% [markdown]
# # Here we will make a new variable which is tdf ( True Dataframe )

# %%
true_dataframe = dataframe.dropna()

# %% [markdown]
# # I removed the error by using [dropna]

# %%
true_dataframe
# Out:
#      No_of_movies                                 Name    Year  Duration  \
# 2               3                          #Homecoming  2021.0      90.0
# 4               5                    ...And Once Again  2010.0     105.0
# 6               7                            ...Yahaan  2005.0     142.0
# 7               8                       .in for Motion  2008.0      59.0
# 9              10                             @Andheri  2014.0     116.0
# ..            ...                                  ...     ...       ...
# 714           715                            Agreement  1980.0     124.0
# 715           716                               Agyaat  2009.0     130.0
# 716           717                                Ahaan  2019.0      81.0
# 717           718                       Aham Brahmasmi  2021.0     106.0
# 719           720                              Ahankar  1999.0      75.0
#
#                        Genre  Rating  Votes                   Director  \
# 2             Drama, Musical     7.0      8         Soumyajit Majumdar
# 4                      Drama     4.4     35               Amol Palekar
# 6        Drama, Romance, War     4.7    827             Shoojit Sircar
# 7                Documentary     7.4   1086              Anirban Datta
# 9    Action, Crime, Thriller     5.6    326          Biju Bhaskar Nair
# ..                       ...     ...    ...                        ...
# 714   Musical, Comedy, Drama     4.8      0               Anil Ganguly
# 715   Drama, Horror, Mystery     6.2      0            Ram Gopal Varma
# 716            Comedy, Drama     2.9    620            Nikhil Pherwani
# 717                   Action     7.2    213  Megastar Maharishi Aazaad
# 719                  -------     5.9     53                 Raja Mitra
#
#                  Actor 1             Actor 2           Actor 3
# 2           Sayani Gupta   Plabita Borthakur        Roy Angana
# 4           Rajat Kapoor  Rituparna Sengupta       Antara Mali
# 6        Jimmy Sheirgill      Minissha Lamba    Yashpal Sharma
# 7                -------             -------           -------
# 9              Augustine        Fathima Babu              Byon
# ..                   ...                 ...               ...
# 714                Rekha          Utpal Dutt  Shailendra Singh
# 715              Nithiin    Priyanka Kothari      Rasika Dugal
# 716         Arif Zakaria      Niharika Singh      Abuli Mamaji
# 717              -------             -------           -------
# 719  Soumitra Chatterjee      Indrani Haldar     Rajesh Sharma
#
# [227 rows x 11 columns]

# %%
sns.heatmap(true_dataframe.isnull())
# Out:
# <Axes: >

# %%
true_dataframe.isnull().sum()
# Out:
# No_of_movies    0
#        Name     0
# Year            0
# Duration        0
# Genre           0
# Rating          0
# Votes           0
# Director        0
# Actor 1         0
# Actor 2         0
# Actor 3         0
# dtype: int64

# %%
true_dataframe.shape
# Out:
# (227, 11)

# %%
true_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 227 entries, 2 to 719
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_movies  227 non-null    int64
#  1          Name   227 non-null    object
#  2   Year          227 non-null    float64
#  3   Duration      227 non-null    float64
#  4   Genre         227 non-null    object
#  5   Rating        227 non-null    float64
#  6   Votes         227 non-null    int64
#  7   Director      227 non-null    object
#  8   Actor 1       227 non-null    object
#  9   Actor 2       227 non-null    object
#  10  Actor 3       227 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.3+ KB

# %% [markdown]
# # Now we will check that are there any duplicate values or not

# %%
dup_true_dataframe=true_dataframe.duplicated().any()

# %%
print("is there any duplicate value? : ",dup_true_dataframe)
# Out:
# is there any duplicate value? :  False

# %% [markdown]
# # This means our dataset is clear now

# %% [markdown]
# # I am making another variable for this   [ddf(duplicated dataframe)]

# %%
duplicate_dataframe = true_dataframe.drop_duplicates()
duplicate_dataframe
# Out:
#      No_of_movies                                 Name    Year  Duration  \
# 2               3                          #Homecoming  2021.0      90.0
# 4               5                    ...And Once Again  2010.0     105.0
# 6               7                            ...Yahaan  2005.0     142.0
# 7               8                       .in for Motion  2008.0      59.0
# 9              10                             @Andheri  2014.0     116.0
# ..            ...                                  ...     ...       ...
# 714           715                            Agreement  1980.0     124.0
# 715           716                               Agyaat  2009.0     130.0
# 716           717                                Ahaan  2019.0      81.0
# 717           718                       Aham Brahmasmi  2021.0     106.0
# 719           720                              Ahankar  1999.0      75.0
#
#                        Genre  Rating  Votes                   Director  \
# 2             Drama, Musical     7.0      8         Soumyajit Majumdar
# 4                      Drama     4.4     35               Amol Palekar
# 6        Drama, Romance, War     4.7    827             Shoojit Sircar
# 7                Documentary     7.4   1086              Anirban Datta
# 9    Action, Crime, Thriller     5.6    326          Biju Bhaskar Nair
# ..                       ...     ...    ...                        ...
# 714   Musical, Comedy, Drama     4.8      0               Anil Ganguly
# 715   Drama, Horror, Mystery     6.2      0            Ram Gopal Varma
# 716            Comedy, Drama     2.9    620            Nikhil Pherwani
# 717                   Action     7.2    213  Megastar Maharishi Aazaad
# 719                  -------     5.9     53                 Raja Mitra
#
#                  Actor 1             Actor 2           Actor 3
# 2           Sayani Gupta   Plabita Borthakur        Roy Angana
# 4           Rajat Kapoor  Rituparna Sengupta       Antara Mali
# 6        Jimmy Sheirgill      Minissha Lamba    Yashpal Sharma
# 7                -------             -------           -------
# 9              Augustine        Fathima Babu              Byon
# ..                   ...                 ...               ...
# 714                Rekha          Utpal Dutt  Shailendra Singh
# 715              Nithiin    Priyanka Kothari      Rasika Dugal
# 716         Arif Zakaria      Niharika Singh      Abuli Mamaji
# 717              -------             -------           -------
# 719  Soumitra Chatterjee      Indrani Haldar     Rajesh Sharma
#
# [227 rows x 11 columns]

# %%
duplicate_dataframe.describe()
# Out:
#        No_of_movies         Year    Duration      Rating         Votes
# count    227.000000   227.000000  227.000000  227.000000    227.000000
# mean     331.215859  1996.964758  128.251101    5.661233    930.118943
# std      220.755966    19.679930   28.405151    1.329413   3392.521840
# min        3.000000  1938.000000   45.000000    2.500000      0.000000
# 25%      127.500000  1985.000000  110.000000    4.700000     14.500000
# 50%      329.000000  2001.000000  130.000000    5.700000     61.000000
# 75%      502.500000  2013.500000  148.000000    6.700000    338.000000
# max      720.000000  2021.000000  240.000000    8.100000  27357.000000

# %%
duplicate_dataframe.describe(include='all')
# Out:
#         No_of_movies               Name         Year    Duration  Genre  \
# count     227.000000                227   227.000000  227.000000    227
# unique           NaN                209          NaN         NaN     89
# top              NaN                             NaN         NaN  Drama
# freq             NaN                  6          NaN         NaN     27
# mean      331.215859                NaN  1996.964758  128.251101    NaN
# std       220.755966                NaN    19.679930   28.405151    NaN
# min         3.000000                NaN  1938.000000   45.000000    NaN
# 25%       127.500000                NaN  1985.000000  110.000000    NaN
# 50%       329.000000                NaN  2001.000000  130.000000    NaN
# 75%       502.500000                NaN  2013.500000  148.000000    NaN
# max       720.000000                NaN  2021.000000  240.000000    NaN
#
#             Rating         Votes       Director        Actor 1  \
# count   227.000000    227.000000            227            227
# unique         NaN           NaN            206            173
# top            NaN           NaN  J. Om Prakash  Rajesh Khanna
# freq           NaN           NaN              6              7
# mean      5.661233    930.118943            NaN            NaN
# std       1.329413   3392.521840            NaN            NaN
# min       2.500000      0.000000            NaN            NaN
# 25%       4.700000     14.500000            NaN            NaN
# 50%       5.700000     61.000000            NaN            NaN
# 75%       6.700000    338.000000            NaN            NaN
# max       8.100000  27357.000000            NaN            NaN
#
#                 Actor 2          Actor 3
# count               227              227
# unique              197              195
# top             -------          -------
# freq                 12               16
# mean                NaN              NaN
# std                 NaN              NaN
# min                 NaN              NaN
# 25%                 NaN              NaN
# 50%                 NaN              NaN
# 75%                 NaN              NaN
# max                 NaN              NaN

# %% [markdown]
# # Our data is clear now

# %%
clear_data = duplicate_dataframe

# %% [markdown]
# # Now movies which are less than 90 minute

# %%
duplicate_dataframe[duplicate_dataframe['Duration']<=90]
# Out:
#      No_of_movies                                              Name    Year  \
# 2               3                                       #Homecoming  2021.0
# 7               8                                    .in for Motion  2008.0
# 50             51                           2 Nights in Soul Valley  2012.0
# 95             96                                         417 Miles  2016.0
# 107           108                            6387 Meters Black Peak  2020.0
# 134           135                                           99.9 FM  2005.0
# 135           136                              A Ballad of Maladies  2016.0
# 144           145                                  A Dream Document  2016.0
# 154           155                             A Mermaid Called Aida  1996.0
# 168           169                                   A Suitable Girl  2017.0
# 192           193                                         Aadamkhor  2018.0
# 218           219                  Aadmi Ki Aurat Aur Anya Kahaniya  2009.0
# 253           254                             Aage Maut Peeche Maut  2001.0
# 273           274                                             Aaina  2019.0
# 280           281                               Aaj Ka Andha Kanoon  2003.0
# 377           378                                      Aamna Saamna  2013.0
# 494           495                                   Aasmaan Se Gira  1992.0
# 530           531                          Ab Hoga Dharna Unlimited  2012.0
# 621           622                                          Adhiktam  2020.0
# 656           657                                    Adwait Sangeet  2011.0
# 716           717                                             Ahaan  2019.0
# 719           720                                           Ahankar  1999.0
#
#      Duration                            Genre  Rating  Votes  \
# 2        90.0                   Drama, Musical     7.0      8
# 7        59.0                      Documentary     7.4   1086
# 50       80.0       Adventure, Horror, Mystery     5.6     14
# 95       75.0                            Drama     7.3   2548
# 107      85.0                      Documentary     5.4      5
# 134      90.0                     Crime, Drama     7.4   1901
# 135      86.0               Documentary, Music     4.8     38
# 144      70.0                      Documentary     7.5   4637
# 154      52.0                      Documentary     7.3     17
# 168      90.0                      Documentary     3.8    627
# 192      72.0                           Horror     5.5      6
# 218      78.0                            Drama     5.0    142
# 253      78.0                           Horror     4.8     30
# 273      60.0                           Horror     3.2      5
# 280      46.0                           Action     6.0      5
# 377      62.0                        Animation     7.7  10862
# 494      88.0       Adventure, Comedy, Romance     5.5      6
# 530      78.0                           Comedy     7.6     80
# 621      45.0                   Action, Comedy     4.9     21
# 656      82.0  Documentary, Biography, Musical     4.6    140
# 716      81.0                    Comedy, Drama     2.9    620
# 719      75.0                          -------     5.9     53
#
#                Director              Actor 1               Actor 2  \
# 2    Soumyajit Majumdar         Sayani Gupta     Plabita Borthakur
# 7         Anirban Datta              -------               -------
# 50        Harish Sharma        Hemant Pandey         Sumeet Sharma
# 95          Mainak Dhar    Marilia Colturato           Kyara Jacob
# 107        Kovid Mittal         Kovid Mittal               -------
# 134       Sanjay Bhatia           Shawar Ali      Rajkumar Kanojia
# 135        Sarvnik Kaur        Tushar Madhav               -------
# 144           Rupak Das              -------               -------
# 154   Riyad Vinci Wadia          Aida Banaji            Ajay Mehta
# 168      Sarita Khurana       Smriti Mundhra          Sima Taparia
# 192      Kshitij Sharma            Deeya Dey         Anoma Pabuwal
# 218          Amit Dutta      Ashok Chaudhary  Bramhaswaroop Mishra
# 253            A.T. Joy          Lekha Pande             Vimal Raj
# 273        Raja Bhargav         Komal Bharti      Urmila Chandolia
# 280  Amit Chandra Sahay         Sudesh Berry      Priyanka Upendra
# 377       Rajiv Chilaka       Jigna Bhardwaj           Rajesh Kava
# 494     Pankaj Parashar  Abhishek Chitlangia        Raghuvir Yadav
# 530       Deepak Tanwar        Saurabh Malik            Rekha Rana
# 621      Prashast Singh       Prashast Singh               -------
# 656     Makarand Brahme              -------               -------
# 716     Nikhil Pherwani         Arif Zakaria        Niharika Singh
# 719          Raja Mitra  Soumitra Chatterjee        Indrani Haldar
#
#                   Actor 3
# 2              Roy Angana
# 7                 -------
# 50          Sumeet Sharma
# 95    Kyara Ralella Jacob
# 107               -------
# 134             Jai Nagra
# 135               -------
# 144               -------
# 154               -------
# 168               -------
# 192  Mahendra Singh Rawat
# 218     Gagan Singh Sethi
# 253               Shakila
# 273             Ankit Jha
# 280           Aman Jalali
# 377          Sabina Malik
# 494           Anupam Kher
# 530   Omkar Das Manikpuri
# 621               -------
# 656               -------
# 716          Abuli Mamaji
# 719         Rajesh Sharma

# %% [markdown]
# This shows that total 23 movies are less than 90 minute

# %% [markdown]
# # Lets check for greater than 200 minute

# %%
duplicate_dataframe[duplicate_dataframe['Duration']>=200]
# Out:
#      No_of_movies                                         Name    Year  \
# 490           491                  Aasma: The Sky Is the Limit  2009.0
#
#      Duration  Genre  Rating  Votes                  Director  \
# 490     240.0  Drama     5.2      8  Rohit Krishnakant Nayyar
#
#              Actor 1       Actor 2         Actor 3
# 490  Hrishitaa Bhatt  Seema Biswas  Nauheed Cyrusi

# %% [markdown]
# This shows that total 1 movie is equal or greater than 200 minute

# %% [markdown]
# # This means that 204 movies are between 90 and 200 minuts

# %% [markdown]
# # Lets find out that how many movies were made between 1940 to 2023

# %%
duplicate_dataframe[duplicate_dataframe['Year']<=1940]
# Out:
#      No_of_movies                       Name    Year  Duration  \
# 552           553                    Abhagin  1938.0     151.0
# 561           562                  Abhilasha  1938.0     134.0
# 590           591                     Achhut  1940.0     140.0
# 617           618                    Adhikar  1938.0     132.0
#
#                Genre  Rating  Votes      Director           Actor 1  \
# 552          -------     4.8     21  Prafulla Roy       Molina Devi
# 561          -------     6.8      0   Zia Sarhadi  Mahendra Thakore
# 590            Drama     6.7     25         Gohar           Motilal
# 617          -------     6.6     28    P.C. Barua        P.C. Barua
#
#                Actor 2                Actor 3
# 552  Prithviraj Kapoor            Vijay Kumar
# 561           M. Kumar                  Bibbo
# 590            Vasanti  Noor Mohammad Charlie
# 617             Jamuna          Pahadi Sanyal

# %% [markdown]
# This shows that the oldest movie was made in 1938

# %% [markdown]
# # Now we will make a graph

# %%
w = clear_data.Votes
x = clear_data.No_of_movies
y = clear_data.Rating
z = clear_data.Duration

# %%
plt.scatter(x,y,marker='*',c='cyan',ec='red',alpha=0.7)
plt.xticks(rotation=60)
plt.xlabel("No. of Movies",fontsize='30')
plt.ylabel("Ratings",fontsize="30")
plt.show()

# %% [markdown]
# # Now Line Plots

# %%
plt.plot(x,y,label='Ratings',c='red',lw=2)
plt.plot(x,z,label='Duration',c='blue',lw=2)
plt.xlabel('No. of Movies',fontsize='20')
plt.ylabel("Ratings,votings and duration of movies",fontsize='10')
plt.xticks (rotation=30)
plt.yticks (rotation=30)
plt.legend()
plt.show()

# %%
plt.plot(x,w,label='Votes',c='red',alpha=0.7,lw=2)
plt.xlabel('No. of Movies',fontsize='20')
plt.ylabel("Votes of movies",fontsize='10')
plt.xticks (rotation=30)
plt.yticks (rotation=30)
plt.legend()
plt.show()

# %% [markdown]
# # Now Histogram of Ratings

# %%
plt.hist(y,bins=30, color="cyan",ec="red", lw=2,)
plt.title("Histogram of Ratings", fontsize=30)
plt.xlabel("Ratings", fontsize=20)
plt.ylabel("No. of Movies",fontsize=20)
plt.show()

# %% [markdown]
# # Now Histogram of Duration

# %%
plt.hist(z,bins=30, color="green",ec="pink", lw=2,)
plt.title("Histogram of Duration", fontsize=30)
plt.ylabel("No. of Movies",fontsize=20)
plt.xlabel("Duration of movies", fontsize=20)
plt.show()

# %% [markdown]
# # Now Histogram of Votes

# %%
plt.hist(w,bins=30, color="green",ec="pink", lw=2,)
plt.title("Histogram of Votes", fontsize=30)
plt.ylabel("No. of Movies",fontsize=20)
plt.xlabel("Votes of movies", fontsize=20)
plt.show()

# %% [markdown]
# # Now Box plot

# %%
plt.boxplot(y)
plt.show()

# %%
plt.boxplot(z)
plt.show()

# %%
plt.boxplot(w)
plt.show()
